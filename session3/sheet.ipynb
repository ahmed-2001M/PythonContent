# %% [markdown]
# # Programming Problems
#
# ## Problem 1: Print Hello World
# Write a program that prints "Hello, World!".
#
# **Input:**
# (no input)
#
# **Output:**
# Hello, World!
#
# ---
#
# ## Problem 2: Basic Arithmetic
# Write a program that takes two integers as input and prints their sum.
#
# **Input:**
# 5
# 10
#
# **Output:**
# 15
#
# ---
#
# ## Problem 3: String Concatenation
# Write a program that takes two strings as input and prints their concatenation.
#
# **Input:**
# Hello
# World
#
# **Output:**
# HelloWorld
#
# ---
#
# ## Problem 4: Variable Types
# Create a program that defines a float, an integer, and a string. Print their types.
#
# **Input:**
# 3.14
# 10
# Hello
#
# **Output:**
# <class 'float'>
# <class 'int'>
# <class 'str'>
#
# ---
#
# ## Problem 5: Even or Odd
# Write a program that takes an integer as input and prints "Even" if it's even and "Odd" if it's odd.
#
# **Input:**
# 4
#
# **Output:**
# Even
#
# ---
#
# ## Problem 6: Maximum of Two
# Write a program that takes two integers as input and prints the maximum.
#
# **Input:**
# 7
# 12
#
# **Output:**
# 12
#
# ---
#
# ## Problem 7: Check if Uppercase
# Write a program that takes a string as input and prints "Yes" if it is in uppercase, otherwise print "No".
#
# **Input:**
# HELLO
#
# **Output:**
# Yes
#
# ---
#
# ## Problem 8: String Length
# Write a program that takes a string as input and prints its length.
#
# **Input:**
# Hello, World!
#
# **Output:**
# 13
#
# ---
#
# ## Problem 10: Slicing Strings
# Write a program that takes a string and two indices as input and prints the sliced string.
#
# **Input:**
# Python
# 0
# 3
#
# **Output:**
# Pyt
#
# ---
#
# ## Problem 11: String to Uppercase
# Write a program that takes a string as input and prints it in uppercase.
#
# **Input:**
# hello
#
# **Output:**
# HELLO
#
# ---
#
# ## Problem 12: String Reversal
# Write a program that takes a string as input and prints it reversed without using loops or functions.
#
# **Input:**
# Python
#
# **Output:**
# nohtyP
#
# ---
#
# ## Problem 13: Check All Alphabetic
# Write a program that takes a string as input and prints "Yes" if all characters are alphabetic, otherwise print "No".
#
# **Input:**
# Hello
#
# **Output:**
# Yes
#
# ---
#
# ## Problem 14: Check All Lowercase
# Write a program that takes a string as input and prints "Yes" if all characters are lowercase, otherwise print "No".
#
# **Input:**
# hello
#
# **Output:**
# Yes
#
# ---
#
# ## Problem 15: Check All Uppercase
# Write a program that takes a string as input and prints "Yes" if all characters are uppercase, otherwise print "No".
#
# **Input:**
# HELLO
#
# **Output:**
# Yes
#
# ---
#
# ## Problem 17: First Character
# Write a program that takes a string as input and prints its first character.
#
# **Input:**
# Python
#
# **Output:**
# P
#
# ---
#
# ## Problem 18: Last Character
# Write a program that takes a string as input and prints its last character.
#
# **Input:**
# Programming
#
# **Output:**
# g
#
# ---
#
# ## Problem 19: ASCII Value
# Write a program that takes a character as input and prints its ASCII value.
#
# **Input:**
# A
#
# **Output:**
# 65
#
# ---
#
# ## Problem 20: Character from ASCII
# Write a program that takes an integer as input and prints the corresponding character.
#
# **Input:**
# 97
#
# **Output:**
# a
